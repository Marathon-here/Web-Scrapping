# %%
import requests
from bs4 import BeautifulSoup
link  = "https://www.youtube.com/@GeeksforGeeksVideos/videos"

# %%
res = requests.get(link)
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="en" darker-dark-theme darker-dark-theme-deprecate system-icons color-version="v2_0" typography typography-spacing><head><script data-id="_gd" nonce="m910JU574AKWWpsR4rwQVg">window.WIZ_global_data = {"AfY8Hf":true,"FL1an":false,"HiPsbb":0,"MUE6Ne":"youtube_web","MuJWjd":false,"UUFaWc":"%.@.null,1000,2]","cfb2h":"youtube.web-front-end-critical_20260304.07_p1","fPDxwd":[],"hsFLT":"%.@.null,1000,2]","iCzhFc":false,"nQyAE":{},"oxN3nb":{"1":false,"0":false,"610401301":false,"899588437":false,"772657768":true,"513659523":false,"568333945":true,"1331761403":false,"651175828":false,"722764542":false,"748402145":false,"748402146":false,"748402147":true,"824648567":true,"824656860":true,"333098724":false,"861377723":false,"861377724":false,"869336903":false},"u4g7r":"%.@.null,1,2]","vJQk6":false,"xnI9P":true,"xwAfE":true,"yFnxrf":2486};</script><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta 
# ...

# %%
soup = BeautifulSoup(res.text, 'html.parser')
# print(soup.prettify())
soup.text
# Out:
# 'GeeksforGeeks - YouTubeAboutPressCopyrightContact usCreatorsAdvertiseDevelopersTermsPrivacyPolicy & SafetyHow YouTube worksTest new featuresNFL Sunday Ticket© 2026 Google LLC'

# %% [markdown]
# By giving direct requests through BeautifulSoup we cannot get the entire data of the page.
#
#
# go to the greekforgreeks https://www.youtube.com/@GeeksforGeeksVideos/videos you observe 1st 8 vedios only once you scroll down you can load more vedios

# %%
#here you can observe that there are no links we are getting just some garbage numbers
soup.find_all('a')
# Out:
# [<a href="/" style="display: none;" title="YouTube"><svg height="20" id="yt-ringo2-svg" viewbox="0 0 93 20" width="93" xmlns="http://www.w3.org/2000/svg"><g><path d="M14.4848 20C14.4848 20 23.5695 20 25.8229 19.4C27.0917 19.06 28.0459 18.08 28.3808 16.87C29 14.65 29 9.98 29 9.98C29 9.98 29 5.34 28.3808 3.14C28.0459 1.9 27.0917 0.94 25.8229 0.61C23.5695 0 14.4848 0 14.4848 0C14.4848 0 5.42037 0 3.17711 0.61C1.9286 0.94 0.954148 1.9 0.59888 3.14C0 5.34 0 9.98 0 9.98C0 9.98 0 14.65 0.59888 16.87C0.954148 18.08 1.9286 19.06 3.17711 19.4C5.42037 20 14.4848 20 14.4848 20Z" fill="#FF0033"></path><path d="M19 10L11.5 5.75V14.25L19 10Z" fill="white"></path></g><g id="youtube-paths"><path d="M37.1384 18.8999V13.4399L40.6084 2.09994H38.0184L36.6984 7.24994C36.3984 8.42994 36.1284 9.65994 35.9284 10.7999H35.7684C35.6584 9.79994 35.3384 8.48994 35.0184 7.22994L33.7384 2.09994H31.1484L34.5684 13.4399V18.8999H37.1384Z"></path><path d="M44.1003 6.29994C41.0703 6.29994 40.0303 8.04994 40.0303 11.8199
# ...

# %% [markdown]
# **Web Drivers**
# #### -> automate the process the web browsers to automate the process for web scrapping  .......we use selenium
#
#
#
# #### -> we will not send direct requests we will send the requests through web browser

# %%
#!pip install selenium
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 39.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.3/510.3 kB 44.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 16.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ...

# %%
from selenium import webdriver

# %%
#!pip install chromedriver_binary
import chromedriver_binary

# %% [markdown]
# In selenium we have different webdriver for different browsers
